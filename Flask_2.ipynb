# %% [markdown]
# <a href="https://colab.research.google.com/github/iamkarandeepsingh/PhysicsWallah/blob/main/Flask_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1. Explain GET and POST methods.

# %% [markdown]
# Ans1.GET and POST are two common HTTP methods used for request-response communication between a client and a server. GET is used to **request data** from a specified resource, while POST is used to **send data** to a server to create/update a resource.
#
# The data sent in a GET request is appended to the URL, while the data sent in a POST request is stored in the request body of the HTTP request. GET requests can be cached, remain in the browser history, and have length restrictions. They should never be used when dealing with sensitive data, On the other hand, POST requests are never cached, do not remain in the browser history, cannot be bookmarked, and have no restrictions on data length.

# %% [markdown]
# Q2. Why is request used in Flask?

# %% [markdown]
# Ans2.In Flask, the request object contains all the data sent from the client to the server. This data can be recovered using the GET/POST methods. The request object holds all incoming data from the request, which includes the mimetype, referrer, IP address, raw data, HTTP method, and headers, among other things.
#
# Flask automatically pushes a request context when handling a request. Because a worker handles only one request at a time, the request data can be considered global to that worker during that request

# %% [markdown]
# Q3. Why is redirect() used in Flask?

# %% [markdown]
# Ans3.The redirect() function in Flask is used to send the user to a particular URL with a specified status code. This function is useful because it allows you to tell your app which URL it should go to when a certain action is performed by an end-user. Redirects are also useful for managing URLs in your application.

# %% [markdown]
# Q4. What are templates in Flask? Why is the render_template() function used?

# %% [markdown]
# Ans4.Templates in Flask are files that can contain both fixed and dynamic content. They allow you to efficiently write easy-to-maintain HTML pages. Flask uses the Jinja templating language to render HTML templates.
#
# The render_template() function is used to generate output from a template file based on the Jinja2 engine. This function can take keyword arguments to pass data to the template 2. The template file is located in the application’s templates folder.

# %% [markdown]
# Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %%
from flask import Flask,request ,jsonify
app = Flask(__name__)

@app.route('/postman_action',methods=['POST'])
def math_ops1():
    if(request.method == 'POST'):
        ops = request.json['operation']
        num1 = int(request.json['num1'])
        num2 = int(request.json['num2'])
        if ops == 'add':
            r = num1+num2
            result = "The sum of " + str(num1) + 'and ' + str(num2) + "is " + str(r)
        if ops == 'subtract':
            r = num1-num2
            result = "The subtract of " + str(num1) + 'and ' + str(num2) + "is " + str(r)
        if ops == 'multiply':
            r = num1*num2
            result = "The multiply of " + str(num1) + 'and ' + str(num2) + "is " + str(r)
        if ops == 'divide':
            r = num1/num2
            result = "The divide of " + str(num1) + 'and ' + str(num2) + "is " + str(r)

        return jsonify(result)

if __name__=="__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# INFO:werkzeug:Press CTRL+C to quit

# %% [markdown]
# ![Postman.jpg](data:image/jpeg;base64,...)
